# %% [markdown]
# # Matplotlib 예시들

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('y label')
plt.xlabel('x label')
# plt.plot([1,2,3,4],[1,2,3,4])
plt.show()

# %%
import numpy as np
x = np.arange(100)
plt.plot(x**2)
plt.axis([0,100,0,100])
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %%
x = np.arange(-20,20)
y1 = 2*x
y2 = (1/3) * x ** 2 + 5
y3 = -x ** 2 - 5

plt.plot(x,y1,'g--',x,y2,'r^-',x,y3,'b*:')
plt.axis([-30,30,-30,30])
# Out:
# (-30.0, 30.0, -30.0, 30.0)

# %%
n = int(input(''))
x = np.arange(n)
y = np.random.random(size = n)

plt.plot(x,y,'g^:')

# %%
x = np.linspace(0,np.pi * 2, 100) # pi * 2 는 360도에 해당함
fig = plt.figure()
plt.plot(x, np.sin(x), 'r-')
plt.plot(x, np.cos(x), 'b:')

fig.savefig('./예제문서파일/sin_cos_fig.png')

# %%
from IPython.display import Image
Image('./예제문서파일/sin_cos_fig.png')

# %%
x = np.linspace(0,np.pi * 2,100)
plt.title('Sin Cos Curve')
plt.plot(x, np.sin(x), 'r-', label = 'sin curve')
plt.plot(x, np.cos(x), 'b:', label = 'cos curve')
plt.xlabel('x value')
plt.ylabel('y value')
plt.legend(loc = 'best')
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15744\1145947374.py:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# 가능한 style을 보여줌
plt.style.available

# default로 다시 변경
# plt.style.use('default')
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.plot([2,3,4],[4,9,16])

from matplotlib import font_manager, rc
font_fname = 'C:/windows/fonts/HANBatang.ttf'
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)
  
plt.title('실습1')
plt.xlabel('x data')
plt.ylabel('y data')
plt.show()
# Out:
# c:\Users\admin\miniconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\admin\miniconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
t = np.arange(0,10,2)
plt.plot(t,t)
plt.plot(t,t**2)
plt.plot(t,t**3)
# 또는
# plot.plot(t,t, t,t**2, t,t**3)

plt.xlabel('x data')
plt.ylabel('y data')
# plt.grid()
plt.show()

# %%
plt.scatter(3,5)
plt.title('pracatice scatter function', fontsize = 15)
plt.show()

# %%
x = np.arange(0,10,1)
plt.scatter(x,x**2,c ='red', s = 10)
plt.text(3,50, 'y=x^2 graph')
plt.show()

# %%
x = np.arange(1,10)
y1 = x*5
y2 = x**5

plt.xlim(2,5)
plt.ylim(5,100)
plt.plot(x,y1,'r',label = 'first')
plt.plot(x,y2,'g', label = 'second')

# 화살표 표시
plt.annotate('Annotate', xy = (2,30),xytext=(2.2,40), arrowprops={'color':'green'})

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('matplotlib sample')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ## 객체지향인 Figure, axes

# %%
fig, ax = plt.subplots(2,2)

x = np.random.randn(100)
y = np.random.randn(100)
ax[0,0].scatter(x,y)

x = np.arange(10)
y = np.random.uniform(1,10,10)
ax[0,1].bar(x,y)

x = np.linspace(0,10,100)
y = np.cos(x)
ax[1,0].plot(x,y)

z = np.random.uniform(0,1,(5,5))
ax[1,1].imshow(z)

# %%
# subplots 로 12개 그리기 >> 후 개수 선택
fig, axes = plt.subplots(3,4)
axes[1][2].plot([1,2,3,4])
axes[1][2].set_title('ax[1][2] title')

axes[2][1].bar([1,2,3,4],[1,2,3,4])
axes[2][1].set_title('ax[2][1] title')

plt.tight_layout() # subplot 간 margin이 겹치지 않게 하는 함수
plt.show()

# %%
# subplt으로 다른 크기 그리기
plt.figure(figsize=(8,8))
# plt.subplot(n행,n열,방번호)
plt.subplot(3,2,1)
plt.subplot(3,2,3)
plt.subplot(3,2,5)
plt.subplot(2,2,2)
plt.subplot(2,2,4)
# Out:
# <AxesSubplot: >

# %%
# ex1)
ax221 = plt.subplot(2,2,1)
ax222 = plt.subplot(2,2,2)
ax212 = plt.subplot(2,1,2)

# %%
# ex2)
plt.figure(figsize = (5,10))
plt.subplot(4,2,1)
plt.subplot(4,2,3)
plt.subplot(4,2,(2,4))  # 또는 (2,2,2)
plt.subplot(4,2,(5,6))  # 또는 (4,1,3)
plt.subplot(4,2,7)
plt.subplot(4,2,8)
# Out:
# <AxesSubplot: >

# %%
plt.subplot(221)
trixaxis = np.linspace(-4,4,100)
sinyaxis = np.sin(trixaxis)
cosyaxis = np.cos(trixaxis)
plt.plot(trixaxis, sinyaxis)
plt.plot(trixaxis, cosyaxis)

plt.subplot(223)
logxaxis = np.linspace(1,10,100)
logyaxis = np.log(logxaxis)
plt.plot(logxaxis, logyaxis)

plt.subplot(122)
quadxaxis = np.linspace(-10,10,100)
quadyaxis = quadxaxis**2
plt.plot(quadxaxis, quadyaxis)

plt.show()

# %%
# Bar 차트
x = np.arange(3)
years = ['2010','2011','2012']
domestic = [6891,5832,9302]
foreign = [777,2013,1632]

plt.bar(x,domestic, width = 0.25)
plt.bar(x+ 0.3,foreign, width = 0.25)
plt.xticks(x,years)
plt.show()

# %%
# Bar 차트
x = np.arange(3)
years = ['2010','2011','2012']
domestic = [6891,5832,9302]
foreign = [777,2013,1632]

plt.barh(x,domestic)
plt.barh(x,foreign)
plt.yticks(x,years)
plt.show()

# %%
# 파이 차트
data = [5,4,6,11]
clist = ['red','blue','green','orange']
explode = [.06, .07, .08, .09]
plt.pie(data, autopct = '%.2f%%', colors = clist, explode = explode)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.random((10,10))
plt.imshow(data)

# 색상
plt.colorbar()
plt.jet()
# plt.sping()
# plt.summer()
# plt.autumn()
# plt.winter()

plt.show()

# %%
# 히스토그램을 이용한 정규분포 함수와 확률 밀도 함수 그리기
f1 = np.random.normal(loc = 0, scale = 1, size = 10000)
f2 = np.random.normal(loc = 3, scale = .5, size = 10000)

plt.hist(f1,bins = 200, color = 'red', alpha = .7,
         label = 'loc = 0, scale = 1')
plt.hist(f2,bins = 200, color = 'blue', alpha = .5,
         label = 'loc = 3, scale = .5')

plt.show()

# %%
from scipy.stats import norm

# 평균이 10.0 이고 분산이 3인 1000개 데이터 생성
data = norm.rvs(10.0, 3, size = 1000)

# 히스토그램을 그림
plt.hist(data, bins = 20, density = True, alpha = 0.6, color = 'b')

# 정규분포를 데이터에 피팅함
mu, std = norm.fit(data)

# scipy의 pdf는 평균, 표준편차로부터 확률 밀도 함수 생성
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x,p,'r', linewidth=2)

# %%
# box plot
data1 = np.random.normal(100,10,200)
data2 = np.random.normal(100,40,200)
data3 = np.random.normal(80,40,200)
data4 = np.random.normal(80,60,200)

plt.boxplot([data1,data2,data3,data4])
plt.show()
