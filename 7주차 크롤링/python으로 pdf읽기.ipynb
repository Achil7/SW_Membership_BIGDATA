# %%
## pdf to python

# !pip install PDFplumber

# %%
# pdfplumber를 활용한 python에서 pdf 읽기

import pdfplumber
with pdfplumber.open('./data/woori.pdf') as temp:
    first_page = temp.pages[0]
    
    print(first_page.extract_text())
# Out:
# Daily Forex Live
# 2022.7.26(화)
# 원화 위험자산 투심 개선 연장, FX/Economist 민경원
# eco_min1230@wooribank.com
# 제한적인 하락 시도 FX Sales/Marketer 신승연
# syshin@wooribank.com
# 금일 달러/원 예상: 1,308 ~ 1,314원 NDF 최종호가 저가 고가
# NDF 종가: 1,311.00(스왑포인트 -0.70 고려 시 1,311.70원 전일비 -2.00) 1,310.90/1,311.10 - -
# 시장평균환율(MAR): 1,311.00원
# 금일 전망: 국내증시 외국인 순매수, 월말 수급부담에 하락 예상 오늘 외환시장 주요 이벤트
# 상승요인: 수입업체 결제 수요 유입, 경기침체 우려로 인한 롱심리 지지 08:00 한국 2Q GDP QoQ(A)(예상 0.4%, 이전 0.6%)
# 23:00 미국 7월 리치먼드 연은 제조업(예상 -14, 이전 -11)
# 하락요인: 국내증시 외국인 순매수 연장, 월말 수출업체 네고, 중공업 수주
# 23:00 미국 7월 CB 소비자신뢰(예상 97.0, 이전 98.7)
# 오늘 달러/원은 기술주 위험선호 심리 둔화에도 외국인 원화 위험자산 투심 개선 23:00 미국 6월 신규주택 판매 MoM(예상 -5.4%, 이전 10.7%)
# 세 유지, 월말 네고 유입에 제한적인 하락 시도 예상. 7월 14일 이후 외국인 자
# 금은 20일 하루를 제외하고 유가증권 시장에서 순매수를 유지. 원화 위험자산에
# 대한 투심 회복이 원화 약세 기대를 억누르는 요인으로 작용하는 만큼 오늘도 장
# 중 외국인 자금 순매수 여부 및 규모가 환율 하락 강도를 결정할 공산이 커. 또
# 한 월말을 맞이한 수출업체 네고 경계와 어제 오후 중공업 소주 소식이 전해지며
# 달러/원, 달러지수(vs G10)
# 수급부담이 커지고 있다는 점도 오늘 하락을 점치게 하는 재료.
# 다만 수입업체 결제수요를 비롯한 저가매수는 하단을 경직. 어제자 환시 움직임을
# 복기해 보면 장 초반 네고와 증시 상승을 쫓아갔으나 추가 하락이 제한되자 수입
# 결제를 필두로 한 매수세 유입이 확인. 오늘도 장중 저점에서 실수요 매수가 유입
# 될 가능성이 높으며 장이 얇다는 점을 감안하면 오후 늦게 낙폭을 되감는 패턴이
# 반복될 수 있어. 따라서 오늘 하락 출발한 뒤 증시 외국인 순매수, 월말 네고 유입
# 에 하락압력이 우위를 보이겠으나 저가매수에 막혀 1,310원 초반 중심 등락 전망.
# 전일 동향: 증시 외국인 순매수 유입에도 저가매수 유입에 강보합
# 전일 달러/원은 1,313.7(+0.7)원. 1,313.5원에 출발한 환율은 장 초반 외국인 증 위안화 부동산 개발업체 기금 조성 소식에 달러에 상승
# 시 순매수, 역외 매도 유입에 1,310원 하향이탈에 성공. 하지만 오후 들어 1,308
# 원에서 지지를 받는 모습을 보이자 저가매수와 숏커버 물량이 유입되며 전일 종
# 가를 소폭 상회하며 장을 마감.
# 글로벌 동향: 달러화, 위안화 블록 통화와 파운드화 강세에 하락
# 달러지수: 106.488(-0.058), 유로/달러 1.0221(+0.0008), 달러/엔 136.71(+0.66)
# 달러화는 FOMC를 앞두고 위안화 블록 통화 강세, 파운드화 랠리에 하락 마감.
# 위안화는 아시아장 초반 중국이 부동산 개발업체 지원을 위한 기금 설립을 승인
# 했다는 소식에 강세. 호주 달러도 중국 정부가 부동산 경기부양 강도를 높이고
# 위안화와 위안화 블록 통화 강세로 달러화 소폭 하락 마감
# 있다는 낙관적인 해석이 호주 대중국 수출 증가 기대를 자극하자 0.4% 상승.
# 유로화는 빅스텝이 한 번으로 끝나지 않을 수 있다는 ECB 위원 발언에 소폭 상승.
# 카자크 라트비아 중앙은행 총재는 9월에도 50bp 인상 결정을 내릴 수 있다고 발언.
# 파운드화는 차기 총리 후보 토론회를 앞두고 정치적 불확실성 해소 기대에 상승.
# 뉴욕증시는 FOMC, 기업실적 관망 속 기술주 차익실현에 혼조. 기업실적 발표 시
# 즌을 맞아 당초 우려보다는 양호하다는 평가를 받고 있으나 시장은 보수적으로
# 대응. 이에 7월 들어 뉴욕증시 반등에 일조했던 기술주 롱포지션이 정리되면서
# 에너지, 헬스케어 주식 상승을 상쇄. 한편 장 마감 후 월마트는 2분기와 올해 이
# 익 전망을 낮추고 재고를 정리하기 위해 가격을 인하해야 한다고 발표. 이에 아 출처: 연합인포맥스, Bloomberg, 우리은행 트레이딩부
# 마존, 타깃, 코스트코 등 주요 유통업체 주가가 시간외에서 하락.

# %% [markdown]
# ### 또 다른 방법

# %%
# !pip install pdfminer.six

# %%
from pdfminer.high_level import extract_text

pdf_woori = extract_text('./data/woori.pdf')
print(pdf_woori)
# Out:
#   Daily Forex Live
#
# 2022.7.26(화)
#
# 원화  위험자산  투심  개선  연장,
# 제한적인  하락  시도
#
# 금일  달러/원  예상: 1,308 ~ 1,314원
# NDF  종가: 1,311.00(스왑포인트  -0.70  고려  시  1,311.70원  전일비  -2.00)
# 시장평균환율(MAR): 1,311.00원
#
# FX/Economist  민경원
# eco_min1230@wooribank.com
#
# FX Sales/Marketer  신승연
# syshin@wooribank.com
#
# NDF  최종호가
#
# 저가
#
# 고가
#
# 1,310.90/1,311.10
#
# -
#
# -
#
# 금일  전망:  국내증시  외국인  순매수,  월말  수급부담에  하락  예상
#
# 오늘  외환시장  주요  이벤트
#
# 08:00  한국  2Q GDP QoQ(A)(예상  0.4%,  이전  0.6%)
# 23:00  미국  7월  리치먼드  연은  제조업(예상  -14,  이전  -11)
# 23:00  미국  7월  CB  소비자신뢰(예상  97.0,  이전  98.7)
# 23:00  미국  6월  신규주택 판매 MoM(예상 -5.4%, 이전 10.7%)
#
# 달러/원,  달러지수(vs G10)
#
# 상승요인:  수입업체  결제  수요  유입,  경기침체  우려로  인한  롱심리  지지
#
# 하락요인:  국내증시  외국인  순매수  연장,  월말  수출업체  네고,  중공업  수주
#
# 오늘  달러/원은  기술주  위험선호  심리  둔화에도  외국인  원화  위험자산  투심  개선
#
# 세  유지,  월말  네고  유입에  제한적인  하락  시도  예상.  7월  14일  이후  외국인  자
#
# 금은  20일  하루를  제외하고  유가증권  시장에서  순매수를  유지.  원화  위험자산에
#
# 대한  투심  회복이  원화  약세  기대를  억누르는  요인으로  작용하는  만큼  오늘도  장
#
# 중  외국인  자금  순매수  여부  및  규모가  환율  하락  강도를  결정할  공산이  커.  또
#
# 한  월말을  맞이한  수출업체  네고  경계와  어제  오후  중공업  소주  소식이  전해지며
#
# 수급부담이  커지고  있다는  점도  오늘  하락을  점치게  하는  재료.
#
# 다만  수입업체  결제수요를  비롯한  저가매수는  하단을  경직.  어제자  환시  움직임을
#
# 복기해  보면  장  초반  네고와  증시  상승을  쫓아갔으나  추가  하락이  제한되자  수입
#
# 결제를  필두로  한  매수세  유입이  확인.  오늘도  장중  저점에서  실수요  매수가  유입
#
# 될  가능성이  높으며  장이  얇다는  점을  감안하면  오후  늦게  낙폭을  되감는  패턴이
#
# 반복될  수  있어.  따라서  오늘  하락  출발한  뒤  증시  외국인  순매수,  월말  네고  유입
#
# 에  하락압력이  우위를  보이겠으나  저가매수에  막혀  1,310원  초반  중심  등락  전망.
#
# 전일  동향:  증시  외국인  순매수  유입에도  저가매수  유입에  강보합
#
# 전일  달러/원은  1,313.7(+0.7)원.  1,313.5원에  출발한  환율은  장  초반  외국인  증
#
# 위안화  부동산  개발업체  기금  조성  소식에  달러에  상승
#
# 시  순매수,  역외  매도  유입에  1,310원  하향이탈에  성공.  하지만  오후  들어  1,308
#
# 원에서  지지를  받는  모습을  보이자  저가매수와  숏커버  물량이  유입되며  전일  종
#
# 가를  소폭  상회하며  장을  마감.
#
# 글로벌  동향:  달러화,  위안화  블록  통화와  파운드화  강세에  하락
#
# 달러지수: 106.488(-0.058),  유로/달러  1.0221(+0.0008),  달러/엔  136.71(+0.66)
#
# 달러화는  FOMC를  앞두고  위안화  블록  통화  강세,  파운드화  랠리에  하락  마감.
#
# 위안화는  아시아장  초반  중국이  부동산  개발업체  지원을  위한  기금  설립을  승인
#
# 했다는  소식에  강세.  호주  달러도  중국  정부가  부동산  경기부양  강도를  높이고
#
# 있다는  낙관적인  해석이  호주  대중국  수출  증가  기대를  자극하자  0.4%  상승.
#
# 유로화는  빅스텝이  한  번으로  끝나지  않을  수  있다는  ECB  위원  발언에  소폭  상승.
#
# 카자크  라트비아  중앙은행  총재는  9월에도  50bp  인상  결정을  내릴  수  있다고  발언.
#
# 파운드화는  차기  총리  후보  토론회를  앞두고  정치적  불확실성  해소  기대에  상승.
#
# 뉴욕증시는  FOMC,  기업실적  관망  속  기술주  차익실현에  혼조.  기업실적  발표  시
#
# 즌을  맞아  당초  우려보다는  양호하다는  평가를  받고  있으나  시장은  보수적으로
#
# 대응.  이에  7월  들어  뉴욕증시  반등에  일조했던  기술주  롱포지션이  정리되면서
#
# 에너지,  헬스케어  주식  상승을  상쇄.  한편  장  마감  후  월마트는  2분기와  올해  이
#
# 위안화와  위안화  블록  통화  강세로  달러화  소폭  하락  마감
#
# 익  전망을  낮추고  재고를  정리하기  위해  가격을  인하해야  한다고  발표.  이에  아
#
# 출처:  연합인포맥스, Bloomberg,  우리은행  트레이딩부
#
# 마존,  타깃,  코스트코  등  주요  유통업체  주가가  시간외에서  하락.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Daily Forex Live
#
#  2
#
# 전일  SPOT  종가                                                                                                                                                                                                                    (단위:  원,  억달러)
#
# 종목
# USD/KRW
# JPY/KRW
# EUR/KRW
# CNH/KRW
#
# 종가
# 1,313.70
# 963.05
# 1,339.18
# 194.44
#
# 전일비
#
# 0.70
# 10.69
# 0.45
# 0.57
#
# 시가
# 1,313.50
# 962.97
# 1,339.21
# 194.07
#
# 고가
# 1,313.80
# 963.55
# 1,339.97
# 194.47
#
# 저가
# 1,308.00
# 959.37
# 1,334.42
# 193.39
#
# 변동폭
#
# 거래량
#
# 전일대비
#
# 5.80
# 4.18
# 5.55
# 1.08
#
# 64.25
# -
# -
# -
#
# (19.61)
# -
# -
# -
#
# 출처:  인포맥스,  우리은행  트레이딩부
#
# 주요통화  환율                                                            아시아/신흥국  통화  환율                                                  FX SWAP POINT                (단위:  원)
#
# 종목
#
# 종가
#
# 전일비
#
# 1주(%)
#
# 종목
#
# 종가
#
# 전일비
#
# 1주(%)
#
# USD Index
#
# 106.488
#
# (0.058)
#
# (0.89)
#
# USD/KRW
#
# 1,313.70
#
# 0.70
#
# EUR/USD
#
# 1.0221
#
# 0.0008
#
# 0.78
#
# USD/SGD
#
# 1.3864
#
# (0.0010)
#
# (0.28)
#
# (0.74)
#
# USD/JPY
#
# 136.71
#
# 0.66
#
# (1.03)
#
# USD/IDR
#
# 14995
#
# (32)
#
# 0.05
#
# GBP/USD
#
# 1.2041
#
# 0.0035
#
# 0.75
#
# USD/PHP
#
# 55.81
#
# (0.33)
#
# (0.96)
#
# USD/CNH
#
# 6.7520
#
# (0.0049)
#
# (0.12)
#
# USD/RUB
#
# 58.5000
#
# 0.3750
#
# 0.00
#
# USD/CHF
#
# 0.9642
#
# 0.0031
#
# (1.40)
#
# USD/ZAR
#
# 16.7846
#
# (0.0460)
#
# AUD/USD
#
# 0.6953
#
# 0.0030
#
# 2.11
#
# USD/MXN
#
# 20.4670
#
# (0.0787)
#
# NZD/USD
#
# 0.6264
#
# 0.0014
#
# 1.79
#
# USD/PLN
#
# 4.6208
#
# (0.0166)
#
# (1.95)
#
# (0.00)
#
# (2.27)
#
# 만기
# 1M
#
# 2M
#
# 3M
#
# 6M
#
# 12M
#
# Mid
#
# 전일비
#
# (0.70)
#
# (1.40)
#
# (2.55)
#
# (6.50)
#
# (12.80)
#
# (0.10)
#
# (0.20)
#
# (0.35)
#
# (0.10)
#
# (0.10)
#
#   한국  CDS Premium            (단위: bp)
# 전일비
#
# 만기
#
# Mid
#
# USD/CAD
#
# 1.2847
#
# (0.0071)
#
# (0.99)
#
# USD/TRY
#
# 17.7687
#
# 0.0460
#
# 1.74
#
# 5Y
#
# 45.230
#
# (1.525)
#
# 출처:  인포맥스,  우리은행  트레이딩부  /  주:  뉴욕시장  종가  기준(한국시간  06:00)
#
# IRS(vs 3M CD)                                            (단위: %, %p)            한국/미국(SOFR)  단기금리                                                                          (단위: %, bp)
#
# 만기
#
# Offer
#
# Bid
#
# Mid
#
# 전일비
#
# 1Y
#
# 2Y
#
# 3Y
#
# 4Y
#
# 5Y
#
# 3.175
#
# 3.255
#
# 3.215
#
# 3.175
#
# 3.140
#
# 3.145
#
# 3.220
#
# 3.185
#
# 3.140
#
# 3.110
#
# 3.160
#
# (0.048)
#
# 3.238
#
# (0.073)
#
# 3.200
#
# (0.075)
#
# 3.158
#
# (0.083)
#
# 3.125
#
# (0.085)
#
# 한국
# 기준
#
# RP(7일)
#
# CD
#
# 통안3M
#
# 통안1Y
#
# 종가
#
# 전일비
#
# 2.25
#
# 2.25
#
# 2.59
#
# 2.284
#
# 2.988
#
# 0.00
#
# 0.00
#
# 0.01
#
# 0.80
#
# 미국
#
# 기준
#
# 1M
#
# 3M
#
# 6M
#
# (0.50)
#
# 12M
#
# 종가
#
# 전일비
#
# 1.75
#
# 2.2861
#
# 2.5291
#
# 2.8934
#
# 3.0613
#
# 0.00
#
# 0.15
#
# (2.97)
#
# (8.58)
#
# (17.38)
#
# CRS(vs 3M SOFR)                                      (단위: %, bp)
# 전일비
# Bid
#
# Offer
#
# Mid
#
# 만기
#
#   국내시장  동향                    (단위: p, %, bp)    외국인  증권투자  동향            (단위:  억원)
# 5일누적
#
# 외인  순매수
#
# 주가/금리
#
# 전일비
#
# 종목
#
# 종목
#
# 1Y
#
# 2Y
#
# 3Y
#
# 4Y
#
# 5Y
#
# 2.409
#
# 1.861
#
# 2.135
#
# 2.580
#
# 2.030
#
# 2.305
#
# 2.564
#
# 2.016
#
# 2.290
#
# 2.429
#
# 1.871
#
# 2.150
#
# 2.364
#
# 1.806
#
# 2.085
#
# (9.00)
#
# (9.50)
#
# (7.50)
#
# (0.11)
#
# (0.11)
#
# KOSPI
#
# KOSDAQ
#
# 국고채3Y
#
# 국고채10Y
#
# 2,403.69
#
# 10.55
#
# KOSPI
#
# 757.97
#
# 3.153
#
# 3.211
#
# 6.49
#
# KOSDAQ
#
# (6.50)
#
# (9.10)
#
# 국고채
#
# 통안채
#
# 출처:  인포맥스,  우리은행  트레이딩부
#
# 901
#
# (660)
#
# 2
#
# 2,188
#
# 5,652
#
# (2,025)
#
# (3,946)
#
# 493
#
# 출처: Bloomberg,  인포맥스,  우리은행  트레이딩부
#
# 글로벌  금융시장                                                                                                                                                                              (단위: p, %, bp,  달러,  달러/톤)
#
# 종가
#
# 전일비
#
# 전일비(%)
#
# 1주(%)
#
# 0.28
#
# 0.13
#
# (0.43)
#
# 0.21
#
# (0.33)
#
# (0.77)
#
# (0.60)
#
# (0.42)
#
# 종목
# 미국채  2Y
#
# 2.95
#
# 3.55    미국채  10Y
#
# 3.72
#
# 2.63
#
# 1.93
#
# -
#
# (0.85)
#
# (1.28)
#
# WTI
#
# Brent
#
# 구리
#
# 니켈
#
# 대두
#
# Gold
#
# 종가
#
# 전일비
#
# 전일비(%)
#
# 1주(%)
#
# 3.0161
#
# 2.7959
#
# 96.70
#
# 105.15
#
# 7,479.00
#
# 22,228.00
#
# 1,473.00
#
# 1,719.10
#
# 4.61
#
# 4.55
#
# 2.00
#
# 1.95
#
# 26.50
#
# 106.00
#
# 38.50
#
# (8.30)
#
# 1.55
#
# 1.65
#
# 2.11
#
# 1.89
#
# 0.36
#
# 0.48
#
# 2.68
#
# (0.48)
#
# (4.99)
#
# (6.35)
#
# (5.75)
#
# (1.05)
#
# 0.71
#
# 7.63
#
# (1.62)
#
# 0.52
#
# 종목
# Dow Jones
#
# S&P
#
# 31,990.04
#
# 3,966.84
#
# 90.75
#
# 5.21
#
# NASDAQ
#
# 11,782.67
#
# (51.45)
#
# EuroStoxx 50
#
# 3,604.16
#
# 7.67
#
# DAX 30
#
# 13,210.32
#
# (43.36)
#
# Nikkei225
#
# Shanghai
#
# Hang Seng H
#
# 27,699.25
#
# (215.41)
#
# 3,250.39
#
# 7,077.09
#
# (19.59)
#
# (29.61)
#
# 출처:  인포맥스, Bloomberg,  우리은행  트레이딩부
#
# 경제지표  및  이벤트
#
# 전일
#
# 금일
#
# 익일
#
# 17:00  독일  7월  IFO  경기신뢰(88.6,  예상  90.1  하회)
# 21:30  미국  6월  시카고연방국가활동(-0.19,  예상  0.00  하회)
# 23:30  미국  7월  댈러스  연은  제조업(-22.6,  예상  -28.5  하회)
#
# 08:00  한국  2Q GDP QoQ(A)(예상  0.4%,  이전  0.6%)
# 23:00  미국  7월  리치먼드  연은  제조업(예상  -14,  이전  -11)
# 23:00  미국  7월  CB  소비자신뢰(예상  97.0,  이전  98.7)
# 23:00  미국  6월  신규주택  판매  MoM(예상  -5.4%,  이전  10.7%)
#
# 10:30  호주  2Q CPI YoY(예상  6.3%,  이전  5.1%)
# 15:00  독일  8월  GfK  소비자기대(예상  -28.9,  이전  -27.4)
# 17:00  유로  6월  M3  통화공급  YoY(예상  5.4%,  이전  5.6%)
# 21:30  미국  6월  내구재  주문  MoM(P)(예상  -0.3%,  이전  0.8%)
# 23:00  미국  6월  미결주택  판매  MoM(예상  -1.0%,  이전  0.7%)
# 03:00  미국  7월  FOMC(예상  75bp  인상)
# 03:30  미국  제롬  파월  연준  의장  연설
#
# 주석: (A)-예비치, (P)-잠정치, (F)-확정치
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Daily Forex Live
#
# Chart
#
# FX Swap Point
#
# CDS Premium
#
#  3
#
# 출처:  인포맥스,  우리은행  트레이딩부
#
# 출처: Bloomberg,  우리은행  트레이딩부
#
# KOSPI  지수,  외국인  순매수  동향
#
# 국내  채권시장  외국인  보유잔고  및  듀레이션
#
# 처:  인포맥스,  우리은행  트레이딩부
#
# 출처:  인포맥스,  우리은행  트레이딩부
#
# 엔/원  환율
#
# 국제유가  및  투기적  포지션  동향
#
# 출처:  인포맥스,  우리은행  트레이딩부
#
# 출처: Bloomberg,  우리은행  트레이딩부
#
# 일간  주요통화  달러대비  절상(절하)율
#
# 일간  신흥국,  아시아통화  달러대비  절상(절하)율
#
# 출처:  인포맥스,  우리은행  트레이딩부  /  주:  뉴욕환시  종가  기준
#
# 출처:  인포맥스,  우리은행  트레이딩부  /  주:  뉴욕환시  종가  기준
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Daily Forex Live
#
#  4
#
# Compliance Notice
#
# 본 자료에 기재된 내용들은 작성자 본인의 의견을 정확하게 반영하고 있으며 외부의 부당한 압력이나 간섭 없이 작성되었음을 확인합니다(작성자: 민경원).
#
# 본 자료는 고객의 투자를 돕기 위한 목적으로 작성되었습니다. 본 자료에 수록된 내용은 당행이 신뢰할 만한 자료 및 정보를 바탕으로 작성한 것이나, 당행이 그 정확성이나 완전성을 보장할
#
# 수 없으므로 참고 자료로만 활용하시기 바라며 투자 시 투자자 자신의 판단과 책임하에 최종 결정을 하시길 바랍니다. 따라서 본 자료는 어떠한 경우에도 고객의 투자 결과에 대한 법적 책임
#
# 소재의 증빙자료로 사용될 수 없으며 직간접적 손실이 발생해도 당행은 책임을 지지 않습니다.
#
# 본  자료는  자본시장법  상  조사분석자료가  아니며  조사분석의  독립성을  확보하기  위한  법적  제한을  받지  않습니다.  또한  법령  상  허용되는  범위  내에서  당행이  본  자료에  언급된  통화  및
#
# 관련 금융상품  등을 거래하거나 관련  금융서비스를 제공할 수 있으며 이와 관련해  당행이  이해관계를 가질 수 있습니다.
#
# 본  자료에  기재된  의견은  예측에  불과하며  별도  통지  없이  변경될  수  있고  일정한  주기로  업데이트  되지  않을  수  있습니다.
#
# 본  자료는  어떠한  경우에도  당행의  사전동의  없이  복사,  인용,  배포,  전송,  대여  및  변경될  수  없습니다.8
