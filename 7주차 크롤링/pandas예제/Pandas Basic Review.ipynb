# %%
import pandas as pd
import numpy as np

chipo_df = pd.read_csv('./data/chipotle.tsv', sep = '\t')

# tsv.파일은 tap으로 되어있는 것
# csv.파일은 comma로 되어있는 것

# %%
# 01. 데이터 살펴보기

chipo_df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# 02. chipo_df.quantity의 값들의 구성을 살펴보기

chipo_df['quantity'].unique()

# 또는
chipo_df['quantity'].value_counts()
# Out:
# 1     4355
# 2      224
# 3       28
# 4       10
# 5        1
# 15       1
# 7        1
# 8        1
# 10       1
# Name: quantity, dtype: int64

# %%
# 03. chipo_df.quantity의 값이 3인 데이터를 추출

chipo_df[chipo_df['quantity'] == 3].reset_index(drop = True)
# Out:
#     order_id  quantity                            item_name  \
# 0        178         3                         Chicken Bowl
# 1        193         3                                 Bowl
# 2        284         3                    Canned Soft Drink
# 3        338         3                        Bottled Water
# 4        350         3                    Canned Soft Drink
# 5        379         3                    Canned Soft Drink
# 6        511         3                        Steak Burrito
# 7        616         3                         Chicken Bowl
# 8        633         3                    Canned Soft Drink
# 9       1051         3                  Chips and Guacamole
# 10      1121         3                        Bottled Water
# 11      1167         3                                Chips
# 12      1170         3                        Side of Chips
# 13      1182         3  Chips and Tomatillo-Red Chili Salsa
# 14      1231         3                    Canned Soft Drink
# ...

# %%
# 04. quantity, item_price 로 구성된 df

qi_df = df[['quantity', 'item_price']]
qi_df
# Out:
#       quantity item_price
# 0            1     $2.39
# 1            1     $3.39
# 2            1     $3.39
# 3            1     $2.39
# 4            2    $16.98
# ...        ...        ...
# 4617         1    $11.75
# 4618         1    $11.75
# 4619         1    $11.25
# 4620         1     $8.75
# 4621         1     $8.75
#
# [4622 rows x 2 columns]

# %%
# 05. qi_df의 itme_price의
# 값을 $표시 없애고
# float타입으로 변경,
# new_price 컬럼을 만들어서 저장

# 모범답안
qi_df['new_price'] = qi_df.item_price.str[1:].astype('float64')
qi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   quantity    4622 non-null   int64
#  1   item_price  4622 non-null   object
#  2   new_price   4622 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 108.5+ KB
# C:\Users\admin\AppData\Local\Temp\ipykernel_15804\942572623.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qi_df['new_price'] = qi_df.item_price.str[1:].astype('float64')
